# %% [markdown]
# # Project: Prompt Engineering with LangChain and Gemini for real-world tasks
#
# - Mini-Project : Research Paper Analyst
#
# ## Install Gemini and LangChain dependencies

# %%
# !pip install langchain==0.1.19
# !pip install langchain-google-Genai==0.0.11
# !pip install langchain-community==0.0.38

# %% [markdown]
# ## Enter API Tokens

# %%
from getpass import getpass

GEMINI_KEY = getpass('Please enter your Gemini API Key here: ')
# Out:
# Please enter your Gemini API Key here: ··········

# %% [markdown]
# ## Setup necessary system environment variables

# %%
import os

os.environ['GEMINI_API_KEY'] = GEMINI_KEY

# %% [markdown]
# ## Load Necessary Dependencies and Gemini LLM

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
gemini = ChatGoogleGenerativeAI(model ="gemini-flash-latest", google_api_key=GEMINI_KEY, convert_system_message_to_human=True, temperature=0.1, streaming=True)

# %%
import google.generativeai as genai

for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-omni-flash-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025

# %% [markdown]
# Run the above cell to see the list of available models. After that, we can adjust the model name in the `gemini` initialization cell accordingly.

# %% [markdown]
# ## Mini-Project : Research Paper Analyst
#
# Make GEMINI act as an AI expert and transform the given research paper abstract based on the nature of the audience mentioned below.
#
# - Short summary of maximum 10 lines for a general audience
# - Detailed report for a healthcare company. Have bullet points for pros and cons of ethics in Generative AI as mentioned in the paper
# - Detailed report for a generative AI company solving healthcare problems. Have bullet points for key points mentioned for Generative AI for text, images and structured data based healthcare

# %%
# Access the Research Paper Abstract
paper_abstract = f"""
The widespread use of ChatGPT and other emerging technology powered by generative
artificial intelligence (AI) has drawn much attention to potential ethical issues, especially in
high-stakes applications such as healthcare.1–3 However, less clear is how to resolve such
issues beyond following guidelines and regulations that are still under discussion and
development. On the other hand, other types of generative AI have been used to synthesize
images and other types of data for research and practical purposes, which have resolved some
ethical issues and exposed other ethical issues,4,5 but such technology is less often the focus
of ongoing ethical discussions. Here we highlight gaps in current ethical discussions of
generative AI via a systematic scoping review of relevant existing research in healthcare, and
reduce the gaps by proposing an ethics checklist for comprehensive assessment and
transparent documentation of ethical discussions in generative AI development. While the
checklist can be readily integrated into the current peer review and publication system to
enhance generative AI research, it may also be used in broader settings to disclose ethicsrelated considerations in generative AI-powered products (or real-life applications of such
products) to help users establish reasonable trust in their capabilities.

Current ethical discussions on generative AI in healthcare
We conducted a systematic scoping review to analyse current ethical discussions on
generative AI in healthcare. Our search in four major academic research databases for
relevant publications from January 2013 to July 2023 yielded 2859 articles (see Methods for
detailed search strategy and Supplementary Figure S1 for the PRISMA flow diagram), of
which 193 articles were included for analysis based on application data modality (text, image,
or structured data), ethical issues discussed, generative AI involved, and whether generative
AI causes or offers technical solutions for issues raised.

Generative AI for text data-based healthcare
Forty-one of the 193 articles discussed ethical considerations pertaining to generative AI
applications for text data, with 20 articles describing methodological developments or
applications of generative AI and the other 21 articles describing review-type works on this
topic. Although some of these review-type articles used the general term “generative AI”, the
main body and supporting evidence focused on LLMs. Twenty-nine articles had in-depth
discussions on ethical issues, whereas the other 12 articles only briefly touched on some
ethical aspects.
Among the 41 articles, 29 articles focused on discussing ethical issues caused by LLMs (and
specifically by GPT in 16 of the articles), covering a wide range of application scenarios and
considered the application of all 10 ethical principles identified in the review (see Figure 1),
as well as other less discussed concerns such as human-AI interaction, and the rights of
LLMs to be considered as co-authors in scientific papers. One paper only commented briefly
on the need for ethical considerations in LLMs and is summarised in the “Others” category.
Although all ethical principles are equally important, some are discussed more often than
others, e.g., non-maleficence (also referred to in the literature as ‘benevolence’), equity, and
privacy.
Fifteen of the 41 articles aimed to resolve some existing ethical issues (for example,
confidentiality of medical data) by using LLMs and other generative AI (e.g., GAN,
autoencoder or diffusion), such as, to reduce privacy concerns by generating synthetic
medical text, to reduce disparity by providing accessible services and assistance, to detect
health-related misinformation, to generate trusted content, and to improve accountability or
transparency over existing approaches. While most articles focused on either identifying
ethical issues caused by generative AI or proposing generative AI-based solutions, three
articles discussed both to provide a more balanced perspective.

Generative AI for image and structured data-based healthcare
Unlike the diverse application scenarios of generative AI based on text data, for image and
structured data, this use of generative AI focuses on data synthesis and encryption. Hence the
majority of articles discussed the methodological developments of generative AI as giving
rise to a more distinctive and focused set of ethical issues.
5
Notably, of the 98 articles on image data and 58 articles on structured data, more than half
(n=63 for image data and n=33 for structured data) only mentioned ethical considerations as a
brief motivation for methodological developments or as a general discussion point. The rest
included more in-depth discussions or evaluations of ethical issues. Among these 155 articles
(as one article covered multiple modalities), 11 articles were review-type work, where 10
articles reviewed methods that mentioned one or two ethical perspectives, and only one
article24 discussed detailed ethical concerns on generative AI applications.
Resolving privacy issues was the main aim of articles for these two data modalities (n=74 for
image data and n=50 for structured data; see Figure 1), predominantly by generating synthetic
data using GAN. Eight articles on image data and 9 articles on structured data used
generative AI to reduce bias, e.g., by synthesizing data for under-represented subgroups in
existing databases. For both data modalities, we did not see explicit discussions on resolving
autonomy, integrity, or morality issues using generative AI, and for structured data the articles
additionally lacked discussions on trust or transparency.
Only 11 articles for image data selectively discussed some ethical issues that generative AI
can give rise to, without specific discussions regarding autonomy, integrity, or morality. For
structured data, only 4 articles discussed equity, privacy, or data security issues caused by
generative AI. Only two articles on structured data included both the cause and resolving
perspectives by discussing ethical issues that may arise from limitations of methods
proposed, specifically bias induced when synthesizing data in order to resolve privacy issues.
"""

# %% [markdown]
# ### Create a prompt template for paper analysis and transformation

# %%
SYS_PROMPT = """
Act as a Artificial Intelligence Expert.
Transform the input research paper abstract given below
based on the instruction input by the user.
"""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", SYS_PROMPT),
        ("human", "{instruction}"),
    ]
)

# %% [markdown]
# ### Create a simple LCEL LLM Chain

# %%
chain = (prompt
            |
         gemini)

# %% [markdown]
# ### Generate the first summary report

# %%
from langchain_core.messages import HumanMessage

prompt_txt = f"""
Based on the following research paper abstract,
create the summary report of maximum 10 lines
for a general audience

Abstract:
{paper_abstract}
"""
messages = [HumanMessage(content=prompt_txt)]
user_instruction = {'instruction': messages}

response = chain.invoke(user_instruction)
messages.append(response)

# %%
print(response.content)
# Out:
# Here is a summary report of the research paper, tailored for a general audience:
#
# 1. **The Challenge:** Generative AI, like ChatGPT, holds great promise for healthcare but raises critical ethical concerns regarding patient privacy, bias, and safety.
# 2. **The Study:** Researchers analyzed 193 scientific papers from the last decade to map out how these ethical issues are currently being discussed and managed.
# 3. **Text-Based AI Risks:** The study revealed that text-based AI (like chatbots) is mostly discussed in terms of the ethical risks it creates, such as spreading misinformation.
# 4. **Image & Data AI Solutions:** In contrast, AI used for medical images and patient files is often viewed as a solution, helping to protect privacy by generating secure "synthetic" data.
# 5. **The Gap:** Despite these insights, many technical papers only briefly mention ethics, exposing a major gap in how AI safety is evaluated.
# 6. **The Solution:** To bridge this gap, the researchers developed a practical "ethics checklist" for AI creators and medical developers.
# 7. **Real-World Impact:** This checklist can be used during scientific reviews and product development to ensure AI tools are transparent and secure.
# 8. **The Goal:** Ultimately, this framework aims to help patients and doctors build well-founded trust in the AI technologies shaping the future of medicine.

# %%
response.content
# Out:
# 'Here is a summary report of the research paper, tailored for a general audience:\n\n1. **The Challenge:** Generative AI, like ChatGPT, holds great promise for healthcare but raises critical ethical concerns regarding patient privacy, bias, and safety.\n2. **The Study:** Researchers analyzed 193 scientific papers from the last decade to map out how these ethical issues are currently being discussed and managed.\n3. **Text-Based AI Risks:** The study revealed that text-based AI (like chatbots) is mostly discussed in terms of the ethical risks it creates, such as spreading misinformation.\n4. **Image & Data AI Solutions:** In contrast, AI used for medical images and patient files is often viewed as a solution, helping to protect privacy by generating secure "synthetic" data.\n5. **The Gap:** Despite these insights, many technical papers only briefly mention ethics, exposing a major gap in how AI safety is evaluated.\n6. **The Solution:** To bridge this gap, the researchers developed a practical "ethics checklist" for AI creators and medical developers.\n7. **Real-World Impact:** This checklist can be used during scientific reviews and product development to ensure AI tools are transparent and secure.\n8. **The Goal:** Ultimately, this framework aims to help patients and doctors build well-founded trust in the AI technologies shaping the future of medicine.'

# %%
messages
# Out:
# [HumanMessage(content='\nBased on the following research paper abstract,\ncreate the summary report of maximum 10 lines\nfor a general audience\n\nAbstract:\n\nThe widespread use of ChatGPT and other emerging technology powered by generative\nartificial intelligence (AI) has drawn much attention to potential ethical issues, especially in\nhigh-stakes applications such as healthcare.1–3 However, less clear is how to resolve such\nissues beyond following guidelines and regulations that are still under discussion and\ndevelopment. On the other hand, other types of generative AI have been used to synthesize\nimages and other types of data for research and practical purposes, which have resolved some\nethical issues and exposed other ethical issues,4,5 but such technology is less often the focus\nof ongoing ethical discussions. Here we highlight gaps in current ethical discussions of\ngenerative AI via a systematic scoping review of relevant existing research in healthcare, and\nreduce the gaps by proposing an ethics checklist for comprehensive assessment and\ntransparent documentation of ethical discussions in generative AI development. While the\nchecklist can be readily integrated into the current peer review and publication system to\nenhance generative AI research, it may also be used in broader settings to disclose ethicsrelated considerations in generative AI-powered products (or real-life applications of such\nproducts) to help users establish reasonable trust in their capabilities.\n\nCurrent ethical discussions on generative AI in healthcare\nWe conducted a systematic scoping review to analyse current ethical discussions on\ngenerative AI in healthcare. Our search in four major academic research databases for\nrelevant publications from January 2013 to July 2023 yielded 2859 articles (see Methods for\ndetailed search strategy and Supplementary Figure S1 for the PRISMA flow diagram), of\nwhich 193 articles were included for analysis based on application data modality (text, image,\nor structured data), ethical issues discussed, generative AI involved, and whether generative\nAI causes or offers technical solutions for issues raised.\n\nGenerative AI for text data-based healthcare\nForty-one of the 193 articles discussed ethical considerations pertaining to generative AI\napplications for text data, with 20 articles describing methodological developments or\napplications of generative AI and the other 21 articles describing review-type works on this\ntopic. Although some of these review-type articles used the general term “generative AI”, the\nmain body and supporting evidence focused on LLMs. Twenty-nine articles had in-depth\ndiscussions on ethical issues, whereas the other 12 articles only briefly touched on some\nethical aspects.\nAmong the 41 articles, 29 articles focused on discussing ethical issues caused by LLMs (and\nspecifically by GPT in 16 of the articles), covering a wide range of application scenarios and\nconsidered the application of all 10 ethical principles identified in the review (see Figure 1),\nas well as other less discussed concerns such as human-AI interaction, and the rights of\nLLMs to be considered as co-authors in scientific papers. One paper only commented briefly\non the need for ethical considerations in LLMs and is summarised in the “Others” category.\nAlthough all ethical principles are equally important, some are discussed more often than\nothers, e.g., non-maleficence (also referred to in the literature as ‘benevolence’), equity, and\nprivacy.\nFifteen of the 41 articles aimed to resolve some existing ethical issues (for example,\nconfidentiality of medical data) by using LLMs and other generative AI (e.g., GAN,\nautoencoder or diffusion), such as, to reduce privacy concerns by generating synthetic\nmedical text, to reduce disparity by providing accessible services and assistance, to detect\nhealth-related misinformation, to generate trusted content, and to improve accountability or\ntran ...
#  AIMessage(content='Here is a summary report of the research paper, tailored for a general audience:\n\n1. **The Challenge:** Generative AI, like ChatGPT, holds great promise for healthcare but raises critical ethical concerns regarding patient privacy, bias, and safety.\n2. **The Study:** Researchers analyzed 193 scientific papers from the last decade to map out how these ethical issues are currently being discussed and managed.\n3. **Text-Based AI Risks:** The study revealed that text-based AI (like chatbots) is mostly discussed in terms of the ethical risks it creates, such as spreading misinformation.\n4. **Image & Data AI Solutions:** In contrast, AI used for medical images and patient files is often viewed as a solution, helping to protect privacy by generating secure "synthetic" data.\n5. **The Gap:** Despite these insights, many technical papers only briefly mention ethics, exposing a major gap in how AI safety is evaluated.\n6. **The Solution:** To bridge this gap, the researchers developed a practical "ethics checklist" for AI creators and medical developers.\n7. **Real-World Impact:** This checklist can be used during scientific reviews and product development to ensure AI tools are transparent and secure.\n8. **The Goal:** Ultimately, this framework aims to help patients and doctors build well-founded trust in the AI technologies shaping the future of medicine.', response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-7cbb1483-36c3-4309-b844-d317051a462b-0')]

# %% [markdown]
# ### Generate the second summary report
#
# Here we add the previous LLM response and the new instructions to the list of messages and send the whole thing to the LLM so it has access to the historical conversation

# %%
prompt_txt = f"""
Use only the research paper abstract from earlier and create a detailed report for a healthcare company.
In the report, also include bullet points (3 max) for pros and cons of ethics in Generative AI
"""
messages.append(HumanMessage(content=prompt_txt))
user_instruction = {'instruction': messages}
response = chain.invoke(user_instruction)
messages.append(response)

# %%
print(response.content)
# Out:
# # Strategic Report: Navigating Generative AI Ethics in Healthcare
# **Prepared by:** Artificial Intelligence Expert
# **Prepared for:** Healthcare Executive Leadership
#
# ---
#
# ### Executive Summary
# As generative Artificial Intelligence (AI) rapidly integrates into clinical and research workflows, healthcare organizations face a dual challenge: leveraging these powerful technologies while navigating complex ethical landscapes. Based on a systematic scoping review of 193 academic articles spanning a ten-year period (2013–2023), this report outlines how generative AI impacts healthcare across different data modalities (text, images, and structured data). It provides actionable insights on how our company can safely deploy these technologies, mitigate risks, and build stakeholder trust.
#
# ---
#
# ### Key Findings by Data Modality
#
# #### 1. Text-Based Generative AI (Large Language Models / GPT)
# Text-based applications, such as Large Language Models (LLMs), present a highly interactive but ethically sensitive domain.
# * **Ethical Risks:** Current literature heavily focuses on the risks LLMs introduce, specifically regarding patient privacy, equity, and "non-maleficence" (the duty to do no harm). Novel ethical dilemmas have also emerged, such as human-AI interaction boundaries and whether LLMs should be credited as co-authors in scientific publications.
# * **Ethical Solutions:** Conversely, LLMs are being developed to solve existing ethical issues by generating synthetic medical text to protect patient confidentiality, detecting health-related misinformation, and providing highly accessible services to reduce healthcare disparities.
#
# #### 2. Image and Structured Data Generative AI (GANs, Autoencoders, Diffusion Models)
# Unlike text, the application of generative AI to medical images and structured patient data is highly focused on data synthesis and encryption.
# * **Ethical Solutions:** These modalities are primarily used as tools to *resolve* ethical issues. Generative Adversarial Networks (GANs) are widely used to generate synthetic patient data to protect privacy. Additionally, they are used to synthesize data for under-represented patient subgroups, directly reducing bias in clinical databases.
# * **The Oversight Gap:** A significant portion of research in these modalities (over half of the analyzed papers) only briefly mentions ethics as a general discussion point or motivation, representing a major gap in active ethical evaluation during technical development.
#
# ---
#
# ### Pros and Cons of Ethics in Generative AI
# Based on the systematic review of generative AI applications in healthcare, the following are the primary ethical advantages (pros) and ethical risks (cons) associated with these technologies:
#
# #### Pros (Ethical Solutions & Benefits)
# * **Advanced Privacy Protection:** Generative AI (specifically GANs and autoencoders) can synthesize highly realistic medical images, text, and structured data, allowing researchers to share and analyze data without compromising real patient confidentiality.
# * **Mitigation of Clinical Bias:** Generative models can actively reduce healthcare disparities by synthesizing data for under-represented demographic subgroups, leading to more equitable and balanced medical databases.
# * **Enhanced Accessibility and Trust:** Text-based generative AI can improve patient care by providing highly accessible services, detecting health-related misinformation, and generating trusted, transparent medical content.
#
# #### Cons (Ethical Risks & Challenges)
# * **Threats to Core Ethical Principles:** If poorly implemented, generative AI can actively cause harm, violate patient privacy, compromise data security, and perpetuate clinical biases (equity issues).
# * **Superficial Ethical Oversight:** There is a severe lack of depth in current technical research; the majority of image and structured data papers only mention ethical considerations superficially, leaving technologies under-evaluated for real-world safety.
# * **Accountability and Transparency Gaps:** Generative AI introduces unresolved challenges regarding human-AI interaction, a lack of transparency in structured data applications, and complex questions regarding intellectual property (such as AI co-authorship).
#
# ---
#
# ### Strategic Recommendation: The Ethics Checklist
# To bridge the gap between rapid AI deployment and ethical safety, our company should adopt the proposed **Ethics Checklist** outlined in the research.
#
# By integrating this comprehensive assessment tool into our internal product development lifecycle and peer-review processes, we can:
# 1. **Ensure Transparent Documentation:** Clearly document how ethical considerations (privacy, equity, non-maleficence) are addressed in every AI-powered product we develop or purchase.
# 2. **Establish User Trust:** Disclose ethics-related considerations to clinicians, patients, and regulators, helping them establish reasonable, well-founded trust in our AI applications.
# 3. **Proactively Align with Regulations:** Position our company ahead of upcoming, highly anticipated healthcare AI regulations and guidelines.

# %%
messages
# Out:
# [HumanMessage(content='\nBased on the following research paper abstract,\ncreate the summary report of maximum 10 lines\nfor a general audience\n\nAbstract:\n\nThe widespread use of ChatGPT and other emerging technology powered by generative\nartificial intelligence (AI) has drawn much attention to potential ethical issues, especially in\nhigh-stakes applications such as healthcare.1–3 However, less clear is how to resolve such\nissues beyond following guidelines and regulations that are still under discussion and\ndevelopment. On the other hand, other types of generative AI have been used to synthesize\nimages and other types of data for research and practical purposes, which have resolved some\nethical issues and exposed other ethical issues,4,5 but such technology is less often the focus\nof ongoing ethical discussions. Here we highlight gaps in current ethical discussions of\ngenerative AI via a systematic scoping review of relevant existing research in healthcare, and\nreduce the gaps by proposing an ethics checklist for comprehensive assessment and\ntransparent documentation of ethical discussions in generative AI development. While the\nchecklist can be readily integrated into the current peer review and publication system to\nenhance generative AI research, it may also be used in broader settings to disclose ethicsrelated considerations in generative AI-powered products (or real-life applications of such\nproducts) to help users establish reasonable trust in their capabilities.\n\nCurrent ethical discussions on generative AI in healthcare\nWe conducted a systematic scoping review to analyse current ethical discussions on\ngenerative AI in healthcare. Our search in four major academic research databases for\nrelevant publications from January 2013 to July 2023 yielded 2859 articles (see Methods for\ndetailed search strategy and Supplementary Figure S1 for the PRISMA flow diagram), of\nwhich 193 articles were included for analysis based on application data modality (text, image,\nor structured data), ethical issues discussed, generative AI involved, and whether generative\nAI causes or offers technical solutions for issues raised.\n\nGenerative AI for text data-based healthcare\nForty-one of the 193 articles discussed ethical considerations pertaining to generative AI\napplications for text data, with 20 articles describing methodological developments or\napplications of generative AI and the other 21 articles describing review-type works on this\ntopic. Although some of these review-type articles used the general term “generative AI”, the\nmain body and supporting evidence focused on LLMs. Twenty-nine articles had in-depth\ndiscussions on ethical issues, whereas the other 12 articles only briefly touched on some\nethical aspects.\nAmong the 41 articles, 29 articles focused on discussing ethical issues caused by LLMs (and\nspecifically by GPT in 16 of the articles), covering a wide range of application scenarios and\nconsidered the application of all 10 ethical principles identified in the review (see Figure 1),\nas well as other less discussed concerns such as human-AI interaction, and the rights of\nLLMs to be considered as co-authors in scientific papers. One paper only commented briefly\non the need for ethical considerations in LLMs and is summarised in the “Others” category.\nAlthough all ethical principles are equally important, some are discussed more often than\nothers, e.g., non-maleficence (also referred to in the literature as ‘benevolence’), equity, and\nprivacy.\nFifteen of the 41 articles aimed to resolve some existing ethical issues (for example,\nconfidentiality of medical data) by using LLMs and other generative AI (e.g., GAN,\nautoencoder or diffusion), such as, to reduce privacy concerns by generating synthetic\nmedical text, to reduce disparity by providing accessible services and assistance, to detect\nhealth-related misinformation, to generate trusted content, and to improve accountability or\ntran ...
#  AIMessage(content='Here is a summary report of the research paper, tailored for a general audience:\n\n1. **The Challenge:** Generative AI, like ChatGPT, holds great promise for healthcare but raises critical ethical concerns regarding patient privacy, bias, and safety.\n2. **The Study:** Researchers analyzed 193 scientific papers from the last decade to map out how these ethical issues are currently being discussed and managed.\n3. **Text-Based AI Risks:** The study revealed that text-based AI (like chatbots) is mostly discussed in terms of the ethical risks it creates, such as spreading misinformation.\n4. **Image & Data AI Solutions:** In contrast, AI used for medical images and patient files is often viewed as a solution, helping to protect privacy by generating secure "synthetic" data.\n5. **The Gap:** Despite these insights, many technical papers only briefly mention ethics, exposing a major gap in how AI safety is evaluated.\n6. **The Solution:** To bridge this gap, the researchers developed a practical "ethics checklist" for AI creators and medical developers.\n7. **Real-World Impact:** This checklist can be used during scientific reviews and product development to ensure AI tools are transparent and secure.\n8. **The Goal:** Ultimately, this framework aims to help patients and doctors build well-founded trust in the AI technologies shaping the future of medicine.', response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-7cbb1483-36c3-4309-b844-d317051a462b-0'),
#  HumanMessage(content='\nUse only the research paper abstract from earlier and create a detailed report for a healthcare company.\nIn the report, also include bullet points (3 max) for pros and cons of ethics in Generative AI\n'),
#  AIMessage(content='# Strategic Report: Navigating Generative AI Ethics in Healthcare\n**Prepared by:** Artificial Intelligence Expert  \n**Prepared for:** Healthcare Executive Leadership  \n\n---\n\n### Executive Summary\nAs generative Artificial Intelligence (AI) rapidly integrates into clinical and research workflows, healthcare organizations face a dual challenge: leveraging these powerful technologies while navigating complex ethical landscapes. Based on a systematic scoping review of 193 academic articles spanning a ten-year period (2013–2023), this report outlines how generative AI impacts healthcare across different data modalities (text, images, and structured data). It provides actionable insights on how our company can safely deploy these technologies, mitigate risks, and build stakeholder trust.\n\n---\n\n### Key Findings by Data Modality\n\n#### 1. Text-Based Generative AI (Large Language Models / GPT)\nText-based applications, such as Large Language Models (LLMs), present a highly interactive but ethically sensitive domain. \n* **Ethical Risks:** Current literature heavily focuses on the risks LLMs introduce, specifically regarding patient privacy, equity, and "non-maleficence" (the duty to do no harm). Novel ethical dilemmas have also emerged, such as human-AI interaction boundaries and whether LLMs should be credited as co-authors in scientific publications.\n* **Ethical Solutions:** Conversely, LLMs are being developed to solve existing ethical issues by generating synthetic medical text to protect patient confidentiality, detecting health-related misinformation, and providing highly accessible services to reduce healthcare disparities.\n\n#### 2. Image and Structured Data Generative AI (GANs, Autoencoders, Diffusion Models)\nUnlike text, the application of generative AI to medical images and structured patient data is highly focused on data synthesis and encryption.\n* **Ethical Solutions:** These modalities are primarily used as tools to *resolve* ethical issues. Generative Adversarial Networks (GANs) are widely used to generate synthetic patient data to protect privacy. Additionally, they are used to synthesize data for under-represented patient subgroups, directly reducing bias in clinical databases.\n* **The Oversight Gap:** A significant portion of research in these modalities (over half of the analyzed papers) only briefly mentions ethics as a general discussion point or motivation, representing a major gap in active ethical evaluation during technical development.\n\n---\n\n### Pros and Cons of Ethics in Generative AI\nBased on the systematic review of generative AI applications in healthcare, the following are the primary ethical advantages (pros) and ethical risks (cons) associated with these technologies:\n\n#### Pros (Ethical Solutions & Benefits)\n* **Advanced Privacy Protection:** Generative AI (specifically GANs and autoencoders) can synthesize highly realistic medical images, text, and structured data, allowing researchers to share and analyze data without compromising real patient confidentiality.\n* **Mitigation of Clinical Bias:** Generative models can actively reduce healthcare disparities by synthesizing data for under-represented demographic subgroups, leading to more equitable and balanced medical databases.\n* **Enhanced Accessibility and Trust:** Text-based generative AI can improve patient care by providing highly accessible services, detecting health-related misinformation, and generating trusted, transparent medical content.\n\n#### Cons (Ethical Risks & Challenges)\n* **Threats to Core Ethical Principles:** If poorly implemented, generative AI can actively cause harm, violate patient privacy, compromise data security, and perpetuate clinical biases (equity issues).\n* **Superficial Ethical Oversight:** There is a severe lack of depth in current technical research; the majority of image and structured data papers only mention ethical considerations superficially, leaving technologie ...

# %% [markdown]
# ### Generate the third summary report
#
# Here we add the previous LLM response and the new instructions to the list of messages and send the whole thing to the LLM so it has access to the historical conversation

# %%
prompt_txt = f"""
Use only the research paper abstract from earlier and create a detailed report for a generative AI company solving healthcare problems.
In the report also include sections for key points mentioned around Generative AI for text, images and structured data based healthcare
"""
messages.append(HumanMessage(content=prompt_txt))
user_instruction = {'instruction': messages}
response = chain.invoke(user_instruction)

# %%
print(response.content)
# Out:
# # Strategic Product & Ethical Report: Generative AI in Healthcare
# **Prepared for:** Executive Leadership and Product Development Teams
# **Prepared by:** Artificial Intelligence Expert
# **Objective:** To analyze the ethical landscape of generative AI in healthcare based on a systematic scoping review of 193 analyzed articles (from a pool of 2,859 publications between January 2013 and July 2023) and translate these findings into actionable product strategies.
#
# ---
#
# ### 1. Generative AI for Text-Based Healthcare (LLMs & GPT)
# Text-based generative AI, primarily Large Language Models (LLMs) like GPT, represents a highly active area of both ethical concern and product opportunity.
# * **Ethical Risks Caused:** Research heavily focuses on the ethical issues these models create. Key concerns span 10 identified ethical principles—most notably **non-maleficence (benevolence), equity, and privacy**. Additionally, unique challenges have emerged regarding human-AI interaction boundaries and the intellectual property rights of LLMs (such as whether they should be credited as co-authors in scientific papers).
# * **Ethical Solutions Provided:** Conversely, LLMs and other generative models (such as GANs, autoencoders, and diffusion models) are actively being used to *resolve* existing healthcare issues. Key applications include:
#   * Generating synthetic medical text to protect patient confidentiality.
#   * Providing highly accessible services and assistance to reduce healthcare disparities.
#   * Detecting health-related misinformation and generating trusted content.
#   * Improving accountability and transparency compared to legacy approaches.
#
# ---
#
# ### 2. Generative AI for Image-Based Healthcare
# For image data, the application of generative AI shifts away from conversational interaction and focuses heavily on data synthesis and encryption.
# * **Primary Use Case (Privacy & Bias Resolution):** The majority of image-based research utilizes Generative Adversarial Networks (GANs) to resolve privacy issues by generating synthetic medical images (74 articles). Additionally, 8 articles demonstrated the use of generative AI to reduce clinical bias by synthesizing image data for under-represented patient subgroups in existing databases.
# * **The Oversight Gap:** There is a severe lack of deep ethical integration in this space. Out of 98 image-based articles, more than half (63 articles) only mentioned ethical considerations as a brief motivation or general discussion point.
# * **Unaddressed Areas:** Only 11 articles discussed the ethical risks that image-generating AI can cause, and there was a complete absence of explicit discussions regarding autonomy, integrity, or morality.
#
# ---
#
# ### 3. Generative AI for Structured Data-Based Healthcare
# Similar to image data, generative AI for structured data (such as electronic health records and patient databases) is highly focused on data synthesis and encryption.
# * **Primary Use Case (Privacy & Bias Resolution):** Synthesizing structured data using GANs is primarily used to resolve privacy issues (50 articles). It is also used to mitigate database bias by generating synthetic data for under-represented subgroups (9 articles).
# * **The Oversight Gap:** Out of 58 structured data articles, more than half (33 articles) only superficially mentioned ethics. Furthermore, this modality completely lacked discussions regarding trust, transparency, autonomy, integrity, or morality.
# * **The "Double-Edge" Risk:** Only 4 articles discussed the ethical risks (equity, privacy, data security) caused by structured data generation. Crucially, only 2 articles addressed the dual perspective of how attempting to solve one issue can cause another—specifically, how **bias can be inadvertently induced when synthesizing structured data to resolve privacy issues**.
#
# ---
#
# ### 4. Pros and Cons of Ethics in Generative AI
# Based on the systematic review, the integration of generative AI in healthcare presents distinct ethical advantages (pros) and critical ethical risks (cons) that our company must navigate:
#
# #### Pros (Ethical Solutions & Capabilities)
# * **Robust Privacy Preservation:** Generative AI (GANs, autoencoders, and diffusion models) can synthesize highly realistic text, images, and structured data, allowing for clinical research and product development without exposing real patient identities.
# * **Active Bias Reduction:** Generative models can intentionally synthesize data for under-represented demographic subgroups, helping to balance clinical databases and reduce systemic disparities.
# * **Trust and Accessibility Facilitation:** Text-based models can be deployed to actively combat health misinformation, generate verified trusted content, and provide accessible assistance to underserved populations.
#
# #### Cons (Ethical Risks & Technical Challenges)
# * **Core Principle Violations:** If unchecked, generative AI can actively violate patient privacy, compromise data security, perpetuate inequity, and violate the principle of non-maleficence (doing no harm).
# * **Superficial Safety Standards:** Over half of the technical research on image and structured data treats ethics as a superficial afterthought rather than a core engineering requirement, leading to under-evaluated technologies.
# * **Secondary Bias Generation:** Technical attempts to solve ethical issues can backfire; for example, synthesizing data to protect patient privacy can inadvertently introduce new, artificial biases into the dataset.
#
# ---
#
# ### 5. Strategic Recommendation: Implementing the "Ethics Checklist"
# To bridge these ethical gaps and differentiate our products in the marketplace, our company should adopt and implement the proposed **Ethics Checklist**.
#
# * **Product Integration:** We must integrate this checklist directly into our product development lifecycle to ensure comprehensive assessment and transparent documentation of all ethical considerations (privacy, equity, non-maleficence).
# * **Market Trust:** By using this checklist to openly disclose ethics-related considerations in our commercial products, we will help clinicians, healthcare providers, and patients establish reasonable, well-founded trust in our AI's capabilities.
# * **Scientific Validation:** Utilizing this checklist aligns our research with emerging peer-review and publication standards, ensuring our clinical validations are robust and regulatory-compliant.
